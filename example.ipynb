# %%
import json
from indec_catalog import generate_catalog

# Generar el catálogo
catalog = generate_catalog(show_progress=True)

print(catalog[:5])
# Out:
# Procesando links: 100%|██████████| 95/95 [01:52<00:00,  1.18s/it]
# ...
