# %%
import json
from indec_catalog import generate_catalog
from indec_catalog.models import Catalog
from typing import List

# Generar el catálogo
catalog : List[Catalog] = generate_catalog(show_progress=True)

print([x for x in catalog if x.tema == "Población"])
# Out:
# Procesando links: 100%|██████████| 95/95 [01:31<00:00,  1.04it/s]
# ...
